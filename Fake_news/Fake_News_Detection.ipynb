# %% [markdown]
# **FAKE NEWS DETECTION**

# %% [markdown]
# Fake news system made to detect the fake news and the real news. This uses the classification techniques of machine learning to predict the dataset and clarify which news is fake of real. I have used logistic regression, decision tree, random forest and gradient boosting classifier to classify the news and see the difference.

# %% [markdown]
# **Imprting Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn import tree
import re
import string

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
fake_news = pd.read_csv('Fake.csv')
true_news = pd.read_csv('True.csv')

# %%
fake_news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true_news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %%
fake_news['class']=0
true_news['class']=1

# %%
fake_news.shape,true_news.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
fake_news_manual_test = fake_news.tail(10)
for i in range(23480, 23470, -1):
    fake_news.drop([i], axis=0, inplace=True)

true_news_manual_test = true_news.tail(10)
for i in range(21416, 21406, -1):
    true_news.drop([i], axis=0, inplace =True)

# %%
fake_news.shape
# Out:
# (23471, 5)

# %%
true_news.shape
# Out:
# (21407, 5)

# %%
fake_news_manual_test['class']=0
true_news_manual_test['class']=1

# %%
fake_news_manual_test.head()
# Out:
#                                                    title  \
# 23471  Seven Iranians freed in the prisoner swap have...
# 23472                      #Hashtag Hell & The Fake Left
# 23473  Astroturfing: Journalist Reveals Brainwashing ...
# 23474          The New American Century: An Era of Fraud
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
#
#                                                     text      subject  \
# 23471  21st Century Wire says This week, the historic...  Middle-east
# 23472   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 23473  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# 23474  Paul Craig RobertsIn the last years of the 20t...  Middle-east
# 23475  Robert Fantina CounterpunchAlthough the United...  Middle-east
#
#                    date  class
# 23471  January 20, 2016      0
# 23472  January 19, 2016      0
# 23473  January 19, 2016      0
# 23474  January 19, 2016      0
# 23475  January 18, 2016      0

# %%
true_news_manual_test.head()
# Out:
#                                                    title  \
# 21407  Mata Pires, owner of embattled Brazil builder ...
# 21408  U.S., North Korea clash at U.N. forum over nuc...
# 21409  U.S., North Korea clash at U.N. arms forum on ...
# 21410  Headless torso could belong to submarine journ...
# 21411  North Korea shipments to Syria chemical arms a...
#
#                                                     text    subject  \
# 21407  SAO PAULO (Reuters) - Cesar Mata Pires, the ow...  worldnews
# 21408  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 21409  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 21410  COPENHAGEN (Reuters) - Danish police said on T...  worldnews
# 21411  UNITED NATIONS (Reuters) - Two North Korean sh...  worldnews
#
#                    date  class
# 21407  August 22, 2017       1
# 21408  August 22, 2017       1
# 21409  August 22, 2017       1
# 21410  August 22, 2017       1
# 21411  August 21, 2017       1

# %%
data = pd.concat([fake_news, true_news], axis=0)
data.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %% [markdown]
# Drop the columns that are not needed, like 'title', 'subject', 'date'.

# %%
data.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
news_detection=data.drop(['title','subject','date'],axis=1)

# %%
news_detection.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
news_detection = news_detection.sample(frac = 1)

# %%
news_detection.head(10)
# Out:
#                                                     text  class
# 17907  Luther Strange will likely be the first and la...      0
# 18747                                                         0
# 7492   Donald Trump is a liar. Not the kind of lies t...      0
# 12663  CAIRO (Reuters) - Palestinian President Mahmou...      1
# 9157   NEW YORK (Reuters) - A federal appeals court f...      1
# 12810  BRUSSELS (Reuters) - Nearly 50,000 people marc...      1
# 3880   WASHINGTON (Reuters) - A meeting of Trump admi...      1
# 19012  COPENHAGEN (Reuters) - Denmark s immigration m...      1
# 14639  NAIROBI (Reuters) - Kenya s Supreme Court will...      1
# 3835   Trump fans may have won the election, but they...      0

# %%
news_detection.reset_index(inplace =True)
news_detection.drop(['index'], axis = 1, inplace = True)

# %%
news_detection.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
news_detection.head(10)
# Out:
#                                                 text  class
# 0  Luther Strange will likely be the first and la...      0
# 1                                                         0
# 2  Donald Trump is a liar. Not the kind of lies t...      0
# 3  CAIRO (Reuters) - Palestinian President Mahmou...      1
# 4  NEW YORK (Reuters) - A federal appeals court f...      1
# 5  BRUSSELS (Reuters) - Nearly 50,000 people marc...      1
# 6  WASHINGTON (Reuters) - A meeting of Trump admi...      1
# 7  COPENHAGEN (Reuters) - Denmark s immigration m...      1
# 8  NAIROBI (Reuters) - Kenya s Supreme Court will...      1
# 9  Trump fans may have won the election, but they...      0

# %% [markdown]
# **Preprocessing**

# %%
def process(text):
    text = text.lower()
    text = re.sub('\[.*?\]','',text)
    text = re.sub("\\W"," ",text)
    text = re.sub('https?://\S+|www\.\S+','',text)
    text = re.sub('<.*?>+',b'',text)
    text = re.sub('[%s]' % re.escape(string.punctuation),'',text)
    text = re.sub('\w*\d\w*','',text)
    return text

# %%
news_detection['text']= news_detection['text'].apply(process)

# %%
X = news_detection['text']
Y = news_detection['class']

# %% [markdown]
# **Training the model**

# %% [markdown]
# *Splitting the dataset in testing set and training set*

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25)

# %%
# converting to vectors
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
XV_train = vectorization.fit_transform(X_train)
XV_test = vectorization.transform(X_test)

# %%
lr = LogisticRegression()
lr.fit(XV_train,Y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = lr.predict(XV_test)

# %%
lr.score(XV_test,Y_test)
# Out:
# 0.9877005347593583

# %%
print (classification_report(Y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5914
#            1       0.98      0.99      0.99      5306
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
DT = DecisionTreeClassifier()
DT.fit(XV_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(XV_test)

# %%
DT.score(XV_test, Y_test)
# Out:
# 0.9951871657754011

# %%
print (classification_report(Y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5914
#            1       0.98      0.99      0.99      5306
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# **Gradient Boost Classifier**

# %%
GB = GradientBoostingClassifier(random_state=0)
GB.fit(XV_train, Y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
pred_gb = GB.predict(XV_test)

# %%
GB.score(XV_test, Y_test)
# Out:
# 0.9949197860962566

# %%
print (classification_report(Y_test, pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5914
#            1       0.99      1.00      0.99      5306
#
#     accuracy                           0.99     11220
#    macro avg       0.99      1.00      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# **Random Forest Classifier**

# %%
RF = RandomForestClassifier()
RF.fit(XV_train , Y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rf = RF.predict(XV_test)

# %%
RF.score(XV_test, Y_test)
# Out:
# 0.991711229946524

# %%
print(classification_report(Y_test, pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5914
#            1       0.99      0.99      0.99      5306
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# *Testing the model*

# %%
def output(n):
    if n==0:
        return 'Fake News'
    elif n==1:
        return 'Not A Fake News'

def manual_test(news):
    test_news = {"text": [news]}
    new_def_test = pd.DataFrame(test_news)
    new_def_test['text'] = new_def_test["text"].apply(process)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_lr = lr.predict(new_xv_test)
    pred_dt = DT.predict(new_xv_test)
    pred_gb = GB.predict(new_xv_test)
    pred_rf = RF.predict(new_xv_test)

    return print ("\n \nlr Prediction: {} \nDT Prediction: {} \nGB Prediction: {} \nRF Prediction: {}". format(output(pred_lr[0]), 
                                                                                                                  output(pred_dt[0]), 
                                                                                                                  output(pred_gb[0]), 
                                                                                                                  output(pred_rf[0])))

# %%
news = str(input())
manual_test(news)
# Out:
#
# lr Prediction: Fake News
# DT Prediction: Fake News
# GB Prediction: Fake News
# RF Prediction: Fake News
